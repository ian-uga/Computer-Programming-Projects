# %%
#Ian Arnold
#Assignment 3

# %%
#6-1 Person
person = {
"first_name": "John",
"last_name": "Mauro",
"age": 21,
"city": "Savannah"}

print(person["first_name"])
print(person["last_name"])
print(person["age"])
print(person["city"])
# Out:
# John
# Mauro
# 21
# Savannah

# %%
#6-2 Favorite Numbers
ian = {
    "first_name": "Ian",
    "favorite_number": 7 }
print(ian["first_name"])
print(ian["favorite_number"])
# Out:
# Ian
# 7

# %%
#6-3 Glossary
glossary = {
    'variable': 'A name used to store a value.',
    'string': 'A series of characters inside quotes.',
    'list': 'A collection of items in a particular order.',
    'if statement': 'A structure that lets you test conditions and act on them.',
    'dictionary': 'A collection of key value pairs used to store related information.' }

print("Variable:\n" + glossary['variable'] + "\n")
print("String:\n" + glossary['string'] + "\n")
print("List:\n" + glossary['list'] + "\n")
print("If Statement:\n" + glossary['if statement'] + "\n")
print("Dictionary:\n" + glossary['dictionary'] + "\n")
# Out:
# Variable:
# A name used to store a value.
#
# String:
# A series of characters inside quotes.
#
# List:
# A collection of items in a particular order.
#
# If Statement:
# A structure that lets you test conditions and act on them.
#
# Dictionary:
# A collection of key value pairs used to store related information.

# %%
#6-4 Glossary 2
glossary = {
    'variable': 'A name used to store a value.',
    'string': 'A series of characters inside quotes.',
    'list': 'A collection of items in a particular order.',
    'if statement': 'A structure that lets you test conditions and act on them.',
    'dictionary': 'A collection of key value pairs used to store related information.',
    'loop': 'A structure for repeating a block of code multiple times.',
    'boolean': 'A value that is either True or False.',
    'function': 'A named block of code that performs a specific task.',
    'tuple': 'An unchangeable list.',
    'comment': 'A note in the code ignored by Python, marked with #.' }

for word, meaning in glossary.items():
    print(f"{word.title()}:\n{meaning}\n")
# Out:
# Variable:
# A name used to store a value.
#
# String:
# A series of characters inside quotes.
#
# List:
# A collection of items in a particular order.
#
# If Statement:
# A structure that lets you test conditions and act on them.
#
# Dictionary:
# A collection of key value pairs used to store related information.
#
# Loop:
# A structure for repeating a block of code multiple times.
#
# Boolean:
# A value that is either True or False.
#
# Function:
# A named block of code that performs a specific task.
#
# Tuple:
# An unchangeable list.
#
# Comment:
# A note in the code ignored by Python, marked with #.

# %%
#6-5 Rivers
rivers = {
    'nile': 'egypt',
    'amazon': 'brazil',
    'oconee': 'the united states'}

for river, country in rivers.items():
    print(f"The {river.title()} runs through {country.title()}.\n")

print("Rivers included:")
for river in rivers.keys():
    print(river.title())

print("\nCountries included:")
for country in rivers.values():
    print(country.title())
# Out:
# The Nile runs through Egypt.
#
# The Amazon runs through Brazil.
#
# The Oconee runs through The United States.
#
# Rivers included:
# Nile
# Amazon
# Oconee
#
# Countries included:
# Egypt
# Brazil
# The United States

# %%
#6-6 Polling
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python'}

people_to_poll = ['jen', 'sarah', 'mike', 'phil', 'anna']

for person in people_to_poll:
    if person in favorite_languages.keys():
        print(f"Thank you, {person.title()}, for taking the poll.")
    else:
        print(f"{person.title()}, please take our favorite languages poll.")
# Out:
# Thank you, Jen, for taking the poll.
# Thank you, Sarah, for taking the poll.
# Mike, please take our favorite languages poll.
# Thank you, Phil, for taking the poll.
# Anna, please take our favorite languages poll.

# %%
#6-7 People
person_1 = {
    "first_name": "John",
    "last_name": "Mauro",
    "age": 21,
    "city": "Savannah" }
person_2 = {
    "first_name": "Sarah",
    "last_name": "Lee",
    "age": 25,
    "city": "Athens" }
person_3 = {
    "first_name": "Michael",
    "last_name": "Brown",
    "age": 30,
    "city": "Atlanta"}

people = [person_1, person_2, person_3]

for person in people:
    print(person["first_name"])
    print(person["last_name"])
    print(person["age"])
    print(person["city"])
    print()
# Out:
# John
# Mauro
# 21
# Savannah
#
# Sarah
# Lee
# 25
# Athens
#
# Michael
# Brown
# 30
# Atlanta

# %%
#6-8 Pets
bella = {
    "animal": "dog",
    "owner": "sarah" }

max = {
    "animal": "cat",
    "owner": "john" }

rocky = {
    "animal": "hamster",
    "owner": "michael"}
pets = [bella, max, rocky]

for pet in pets:
    print(f"Animal: {pet['animal'].title()}")
    print(f"Owner: {pet['owner'].title()}")
    print()
# Out:
# Animal: Dog
# Owner: Sarah
#
# Animal: Cat
# Owner: John
#
# Animal: Hamster
# Owner: Michael

# %%
#6-9 Favorite places
favorite_places = {
    "john": ["savannah", "athens", "tybee"],
    "sarah": ["paris", "rome", "new york"],
    "michael": ["atlanta"] }

for name, places in favorite_places.items():
    print(f"\n{name.title()}'s favorite places are:")
    for place in places:
        print(f"- {place.title()}")
# Out:
# John's favorite places are:
# - Savannah
# - Athens
# - Tybee
#
# Sarah's favorite places are:
# - Paris
# - Rome
# - New York
#
# Michael's favorite places are:
# - Atlanta

# %%
#6-10 Favorite Numbers
favorite_numbers = {
    "john": [13, 21],
    "ian": [7,1],
    "michael": [4,3],
    "riley": [8, 10],
    "chris": [1, 2, 3] }

for name, numbers in favorite_numbers.items():
    print(f"\n{name.title()}'s favorite numbers are:")
    for number in numbers:
        print(f"- {number}")
# Out:
# John's favorite numbers are:
# - 13
# - 21
#
# Ian's favorite numbers are:
# - 7
# - 1
#
# Michael's favorite numbers are:
# - 4
# - 3
#
# Riley's favorite numbers are:
# - 8
# - 10
#
# Chris's favorite numbers are:
# - 1
# - 2
# - 3

# %%
#6-11 Cities
cities = {
    "savannah": {
        "country": "united states",
        "population": "147,000",
        "fact": "savannah is known for its historic squares and oak trees with spanish moss." },
    "tybee": {
        "country": "united states",
        "population": "3,000",
        "fact": "tybee island is a popular beach near savannah with a historic lighthouse." },
    "athens": {
        "country": "united states",
        "population": "127,000",
        "fact": "athens is home to the university of georgia and a vibrant music scene." }
}

for city, info in cities.items():
    print(f"\nCity: {city.title()}")
    print(f" Country: {info['country'].title()}")
    print(f" Population: {info['population']}")
    print(f" Fact: {info['fact'].capitalize()}")
# Out:
# City: Savannah
#  Country: United States
#  Population: 147,000
#  Fact: Savannah is known for its historic squares and oak trees with spanish moss.
#
# City: Tybee
#  Country: United States
#  Population: 3,000
#  Fact: Tybee island is a popular beach near savannah with a historic lighthouse.
#
# City: Athens
#  Country: United States
#  Population: 127,000
#  Fact: Athens is home to the university of georgia and a vibrant music scene.

# %%
#7-1 Rental Car

car = input("What kind of rental car would you like? ")
print(f"Let me see if I can find you a {car.title()}.")
# Out:
# What kind of rental car would you like?  ford
# Let me see if I can find you a Ford.

# %%
#7-2 Restauraunt Seating
people = input("How many people are in your dinner group? ")
people = int(people)
if people > 8:
    print("You'll have to wait for a table.")
else:
    print("Your table is ready.")
# Out:
# How many people are in your dinner group?  5
# Your table is ready.

# %%
#7-3 Multiples of Ten
number = input("Enter a number: ")
number = int(number)
if number % 10 == 0:
    print("That number is a multiple of 10.")
else:
    print("That number is not a multiple of 10.")
# Out:
# Enter a number:  20
# That number is a multiple of 10.

# %%
#7-4 Pizza Toppings
prompt = "\nEnter a pizza topping (or 'quit' to finish): "
while True:
    topping = input(prompt)
    
    if topping.lower() == 'quit':
        break
    else:
        print(f"I'll add {topping} to your pizza.")
# Out:
# Enter a pizza topping (or 'quit' to finish):  sausage
# I'll add sausage to your pizza.
# Enter a pizza topping (or 'quit' to finish):  cheese
# I'll add cheese to your pizza.
# Enter a pizza topping (or 'quit' to finish):  quit

# %%
#7-5 Movie Tickets
prompt = "\nEnter your age (or 'quit' to stop): "

while True:
    age = input(prompt)
    if age.lower() == 'quit':
        break
    age = int(age)
    if age < 3:
        print("Your ticket is free.")
    elif age <= 12:
        print("Your ticket costs $10.")
    else:
        print("Your ticket costs $15.")
# Out:
# Enter your age (or 'quit' to stop):  23
# Your ticket costs $15.
# Enter your age (or 'quit' to stop):  quit

# %%
#7-6 Three Exits
active = True
while active:
    topping = input("Enter a pizza topping (or 'quit' to stop): ")

    if topping == "quit":
        active = False
    else:
        print(f"I'll add {topping} to your pizza.")
# Out:
# Enter a pizza topping (or 'quit' to stop):  cheese
# I'll add cheese to your pizza.
# Enter a pizza topping (or 'quit' to stop):  quit

# %%
while True:
    topping = input("Enter a pizza topping (or 'quit' to stop): ")
    if topping == "quit":
        break
    else:
        print(f"I'll add {topping} to your pizza.")
# Out:
# Enter a pizza topping (or 'quit' to stop):  cheese
# I'll add cheese to your pizza.
# Enter a pizza topping (or 'quit' to stop):  lettuce
# I'll add lettuce to your pizza.
# Enter a pizza topping (or 'quit' to stop):  quit

# %%
topping = ""
while topping != "quit":
    topping = input("Enter a pizza topping (or 'quit' to stop): ")
    if topping != "quit":
        print(f"I'll add {topping} to your pizza.")
# Out:
# Enter a pizza topping (or 'quit' to stop):  chicken
# I'll add chicken to your pizza.
# Enter a pizza topping (or 'quit' to stop):  cheese
# I'll add cheese to your pizza.
# Enter a pizza topping (or 'quit' to stop):  quit

# %%
#7-8 Deli Sandwiches
sandwich_orders = ['chicken', 'turkey', 'ham', 'veggie']
finished_sandwiches = []
while sandwich_orders:
    current_sandwich = sandwich_orders.pop()
    print(f"I made your {current_sandwich} sandwich.")
    finished_sandwiches.append(current_sandwich)

print("\nAll sandwiches have been made:")
for sandwich in finished_sandwiches:
    print(f"- {sandwich.title()} sandwich")
# Out:
# I made your veggie sandwich.
# I made your ham sandwich.
# I made your turkey sandwich.
# I made your chicken sandwich.
#
# All sandwiches have been made:
# - Veggie sandwich
# - Ham sandwich
# - Turkey sandwich
# - Chicken sandwich

# %%
#7-9 No Pastrami
sandwich_orders = ['chicken', 'pastrami', 'turkey', 'pastrami', 'ham', 'veggie', 'pastrami']
finished_sandwiches = []
print("The deli has run out of pastrami.\n")
while 'pastrami' in sandwich_orders:
    sandwich_orders.remove('pastrami')
while sandwich_orders:
    current_sandwich = sandwich_orders.pop()
    print(f"I made your {current_sandwich} sandwich.")
    finished_sandwiches.append(current_sandwich)
    
print("\nAll sandwiches have been made:")
for sandwich in finished_sandwiches:
    print(f"- {sandwich.title()} sandwich")
# Out:
# The deli has run out of pastrami.
#
# I made your veggie sandwich.
# I made your ham sandwich.
# I made your turkey sandwich.
# I made your chicken sandwich.
#
# All sandwiches have been made:
# - Veggie sandwich
# - Ham sandwich
# - Turkey sandwich
# - Chicken sandwich
